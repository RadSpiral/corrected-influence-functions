# %%
import numpy as np
import pandas as pd
from scipy.stats import laplace, norm
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Logistic Ridge Regression Functions
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def loss(beta, X, y, lambda_):
    logits = X @ beta
    log_likelihood = -np.mean(y * logits - np.log(1 + np.exp(logits))) * X.shape[0]
    ridge_penalty = 0.5 * lambda_ * np.sum(beta**2)
    return log_likelihood + ridge_penalty

def gradient(beta, X, y, lambda_):
    prob = sigmoid(X @ beta)
    return -X.T @ (y - prob) + lambda_ * beta

def hessian(beta, X, lambda_):
    prob = sigmoid(X @ beta)
    w = prob * (1 - prob)  # shape (n,)
    WX = X * w[:, np.newaxis]  # same effect as diag
    return X.T @ WX + lambda_ * np.eye(X.shape[1])

def newton_step(beta_init, X, y, lambda_, tol=1e-6, max_iter=100):
    beta = beta_init.copy()
    for step_count in range(1, max_iter + 1):
        grad = gradient(beta, X, y, lambda_)
        hess = hessian(beta, X, lambda_)
        step = np.linalg.solve(hess, grad)
        beta -= step
        if np.linalg.norm(step) < tol:
            return beta, step_count
    return beta, max_iter


# Set seed for reproducibility
np.random.seed(1)

# Parameters
n         = 500  # Fixed sample size
p         = 1000  # Fixed number of features
lambda_   = 0.01  # Regularization constant
beta_star = np.random.normal(0, 1, p)
X         = np.random.normal(0, 1 / np.sqrt(n), (n, p))
logits    = X @ beta_star
prob      = sigmoid(logits)
y         = np.random.binomial(1, prob)
beta_init = np.random.normal(0, 1, p) * 0.01
# Compute Newton steps for beta_hat
beta_hat, steps_used = newton_step(beta_init, X, y, lambda_)
# Compute hat matrix H
# Compute predicted probabilities and weights
p_hat = sigmoid(X @ beta_hat)
w = p_hat * (1 - p_hat)  # shape (n,)

# Weighted design matrix
WX = X * w[:, np.newaxis]  # element-wise multiply each row of X by w_i

# Compute Hessian and its inverse
hessian_matrix = X.T @ WX + lambda_ * np.eye(p)
hessian_inv = np.linalg.solve(hessian_matrix, np.eye(p))  # shape (p, p)

# Compute diagonal of the hat matrix: H_ii = w_i * x_i^T @ hessian_inv @ x_i
H_diag = np.einsum('ij,jk,ik->i', X, hessian_inv, X) * w  # shape (n,)

# Trace of H divided by number of features
tr_H = np.sum(H_diag) / p

print(f"Effective df (tr(H)/p) = {tr_H:.4f}, lambda = {lambda_}, n = {n}, p = {p}, Newton Steps: {steps_used}")
# Out:
# Effective df (tr(H)/p) = 0.3450, lambda = 0.01, n = 500, p = 1000, Newton Steps: 8

# %%
m = 100  # number of unseen test points

# Sample m new test points
X_new      = np.random.normal(0, 1 / np.sqrt(n), size=(m, p))
logits_new = X_new @ beta_star
probs_new  = sigmoid(logits_new)
y_new      = np.random.binomial(1, probs_new)

# Precompute full model predictions for all test points
logits_full = X_new @ beta_hat
loss_full   = -y_new * logits_full + np.log(1 + np.exp(logits_full))  # shape (m,)

# Preallocate arrays (n training points × m test points)
loss_changes        = np.zeros((n, m))
approx_loss_changes = np.zeros((n, m))
influence_values    = np.zeros((n, m))

# Compute full-data gradient and Hessian once
eta = X @ beta_hat
p_hat = sigmoid(eta)
w = p_hat * (1 - p_hat)
WX = X * w[:, np.newaxis]
hessian_matrix = X.T @ WX + lambda_ * np.eye(p)
hessian_matrix_inv = np.linalg.solve(hessian_matrix, np.eye(p))  # shared for all i

# Loop over training points
for i in range(n):
    # Leave-one-out retraining
    X_minus_i = np.delete(X, i, axis=0)
    y_minus_i = np.delete(y, i)

    beta_init_minus_i = np.random.normal(0, 1, p) * 0.01
    beta_hat_minus_i, steps = newton_step(beta_init_minus_i, X_minus_i, y_minus_i, lambda_)

    # True LOO loss on all test points
    logits_minus_i = X_new @ beta_hat_minus_i
    loss_minus_i = -y_new * logits_minus_i + np.log(1 + np.exp(logits_minus_i))  # shape (m,)
    loss_changes[i, :] = loss_minus_i - loss_full

    # First-order approx beta_{/i}
    w_minus_i = np.delete(w, i)
    WX_i = X_minus_i * w_minus_i[:, np.newaxis]
    hessian_i = X_minus_i.T @ WX_i + lambda_ * np.eye(p)
    hessian_i_inv = np.linalg.solve(hessian_i, np.eye(p))

    # First derivative of logistic loss at point i
    p_i = p_hat[i]
    y_i = y[i]
    x_i = X[i]
    grad_i = (p_i - y_i) * x_i

    # First order correction
    beta_tilde_i = beta_hat + hessian_i_inv @ grad_i

    # Loss with approx beta on test points
    logits_tilde_i = X_new @ beta_tilde_i
    loss_tilde_i = -y_new * logits_tilde_i + np.log(1 + np.exp(logits_tilde_i))
    approx_loss_changes[i, :] = loss_tilde_i - loss_full

    # Classical Influence estimates on test loss
    for j in range(m):
        p_new = probs_new[j]
        grad_test = (p_new - y_new[j]) * X_new[j]
        beta_influence_i = beta_hat + hessian_matrix_inv @ grad_i
        logit_influence_i = X_new[j] @ beta_influence_i
        loss_influence_i = -y_new[j] * logit_influence_i + np.log(1 + np.exp(logit_influence_i))
        #influence_values[i, j] = loss_influence_i - loss_full[j] # wrapping the loss around it
        influence_values[i, j] = grad_test @ hessian_matrix_inv @ grad_i

    # Optionally print summary stats per training point
    print(f"Point {i:4d}: ΔLoss = {loss_changes[i,1]:7.4f},  ΔLoss_tilde = {approx_loss_changes[i,1]:7.4f}, Influence = {influence_values[i,1]:9.5f}, Steps = {steps:2d}")
# Out:
# Point    0: ΔLoss = -0.0484,  ΔLoss_tilde = -0.0480, Influence =  -0.01689, Steps =  8
# Point    1: ΔLoss = -0.0051,  ΔLoss_tilde = -0.0051, Influence =  -0.00522, Steps =  8
# Point    2: ΔLoss =  0.0161,  ΔLoss_tilde =  0.0161, Influence =   0.01697, Steps =  8
# Point    3: ΔLoss =  0.0150,  ΔLoss_tilde =  0.0149, Influence =   0.00926, Steps =  8
# Point    4: ΔLoss = -0.0020,  ΔLoss_tilde = -0.0020, Influence =  -0.00355, Steps =  8
# Point    5: ΔLoss = -0.0344,  ΔLoss_tilde = -0.0344, Influence =  -0.02599, Steps =  8
# Point    6: ΔLoss =  0.0023,  ΔLoss_tilde =  0.0023, Influence =   0.00324, Steps =  8
# Point    7: ΔLoss = -0.2047,  ΔLoss_tilde = -0.2060, Influence =  -0.06167, Steps =  8
# Point    8: ΔLoss = -0.0957,  ΔLoss_tilde = -0.0957, Influence =  -0.04472, Steps =  8
# Point    9: ΔLoss =  0.0156,  ΔLoss_tilde =  0.0157, Influence =   0.01160, Steps =  8
# Point   10: ΔLoss =  0.0414,  ΔLoss_tilde =  0.0413, Influence =   0.02692, Steps =  8
# Point   11: ΔLoss = -0.1007,  ΔLoss_tilde = -0.1013, Influence =  -0.04858, Steps =  8
# Point   12: ΔLoss =  0.1033,  ΔLoss_tilde =  0.1033, Influence =   0.05280, Steps =  8
# Point   13: ΔLoss =  0.0537,  ΔLoss_tilde =  0.0535, Influence =   0.01919, Steps =  8
# Point   14: ΔLoss =  0.0116,  ΔLoss_tilde =  0.0114, Influence =   0.00652, Steps =  8
# Point   15: ΔLoss =  0.0153,  ΔLoss_tilde =  0.0152, Influence =   0.01069, Steps =  8
# Point   16: ΔLoss = -0.0443,  ΔLoss_tilde = -0.0444, Influence =  -0.02050, Steps =  8
# Point   17: ΔLoss = -0.0397,  ΔLoss_tilde = -0.0396, Influence =  -0.01736, Steps =  8
# Point   18: ΔLoss =  0.0557,  ΔLoss_tilde =  0.0565, Influence =   0.01084, Steps =  8
# Point   19: ΔLoss = -0.0452,  ΔLoss_tilde = -0.0449, Influence =  -0.01792, Steps =  8
# Point   20: ΔLoss = -0.0154,  ΔLoss_tilde = -0.0152, Influence =  -0.00422, Steps =  8
# Point   21: ΔLoss =  0.0000,  ΔLoss_tilde =  0.0001, Influence =   0.00003, Steps =  8
# Point   22: ΔLoss = -0.1711,  ΔLoss_tilde = -0.1702, Influence =  -0.05242, Steps =  8
# Point   23: ΔLoss =  0.1790,  ΔLoss_tilde =  0.1805, Influence =   0.03798, Steps =  8
# Point   24: ΔLoss = -0.0039,  ΔLoss_tilde = -0.0039, Influence =  -0.00331, Steps =  8
# Point   25: ΔLoss =  0.0020,  ΔLoss_tilde =  0.0022, Influence =   0.00083, Steps =  8
# Point   26: ΔLoss = -0.0600,  ΔLoss_tilde = -0.0603, Influence =  -0.03457, Steps =  8
# Point   27: ΔLoss =  0.0540,  ΔLoss_tilde =  0.0539, Influence =   0.03211, Steps =  8
# Point   28: ΔLoss =  0.0029,  ΔLoss_tilde =  0.0028, Influence =   0.00115, Steps =  8
# Point   29: ΔLoss = -0.0410,  ΔLoss_tilde = -0.0409, Influence =  -0.01289, Steps =  8
# Point   30: ΔLoss =  0.0264,  ΔLoss_tilde =  0.0264, Influence =   0.01440, Steps =  8
# Point   31: ΔLoss =  0.1008,  ΔLoss_tilde =  0.1010, Influence =   0.04294, Steps =  8
# Point   32: ΔLoss = -0.0207,  ΔLoss_tilde = -0.0217, Influence =  -0.00592, Steps =  8
# Point   33: ΔLoss =  0.0002,  ΔLoss_tilde =  0.0002, Influence =   0.00020, Steps =  8
# Point   34: ΔLoss =  0.1049,  ΔLoss_tilde =  0.1047, Influence =   0.05925, Steps =  8
# Point   35: ΔLoss =  0.0041,  ΔLoss_tilde =  0.0041, Influence =   0.00327, Steps =  8
# Point   36: ΔLoss = -0.0021,  ΔLoss_tilde = -0.0021, Influence =  -0.00101, Steps =  8
# Point   37: ΔLoss =  0.2107,  ΔLoss_tilde =  0.2099, Influence =   0.05129, Steps =  8
# Point   38: ΔLoss =  0.0320,  ΔLoss_tilde =  0.0321, Influence =   0.02479, Steps =  8
# Point   39: ΔLoss =  0.1416,  ΔLoss_tilde =  0.1410, Influence =   0.03564, Steps =  8
# Point   40: ΔLoss =  0.0007,  ΔLoss_tilde =  0.0007, Influence =   0.00054, Steps =  8
# Point   41: ΔLoss = -0.0034,  ΔLoss_tilde = -0.0033, Influence =  -0.00194, Steps =  8
# Point   42: ΔLoss = -0.0528,  ΔLoss_tilde = -0.0514, Influence =  -0.01517, Steps =  8
# Point   43: ΔLoss = -0.1548,  ΔLoss_tilde = -0.1552, Influence =  -0.06032, Steps =  8
# Point   44: ΔLoss =  0.0057,  ΔLoss_tilde =  0.0053, Influence =   0.00233, Steps =  8
# Point   45: ΔLoss =  0.0012,  ΔLoss_tilde =  0.0012, Influence =   0.00126, Steps =  8
# Point   46: ΔLoss = -0.0005,  ΔLoss_tilde = -0.0006, Influence =  -0.00019, Steps =  8
# Point   47: ΔLoss = -0.0781,  ΔLoss_tilde = -0.0764, Influence =  -0.02035, Steps =  8
# Point   48: ΔLoss = -0.0335,  ΔLoss_tilde = -0.0337, Influence =  -0.01300, Steps =  8
# Point   49: ΔLoss =  0.0019,  ΔLoss_tilde =  0.0019, Influence =   0.00335, Steps =  8
# Point   50: ΔLoss = -0.0157,  ΔLoss_tilde = -0.0157, Influence =  -0.01935, Steps =  8
# Point   51: ΔLoss = -0.0371,  ΔLoss_tilde = -0.0369, Influence =  -0.01344, Steps =  8
# Point   52: ΔLoss =  0.0043,  ΔLoss_tilde =  0.0043, Influence =   0.00645, Steps =  8
# Point   53: ΔLoss =  0.0581,  ΔLoss_tilde =  0.0584, Influence =   0.01886, Steps =  8
# Point   54: ΔLoss =  0.0129,  ΔLoss_tilde =  0.0127, Influence =   0.00643, Steps =  8
# Point   55: ΔLoss =  0.0443,  ΔLoss_tilde =  0.0441, Influence =   0.02330, Steps =  8
# Point   56: ΔLoss =  0.0323,  ΔLoss_tilde =  0.0323, Influence =   0.00788, Steps =  8
# Point   57: ΔLoss = -0.0114,  ΔLoss_tilde = -0.0114, Influence =  -0.00995, Steps =  8
# Point   58: ΔLoss = -0.0130,  ΔLoss_tilde = -0.0135, Influence =  -0.00459, Steps =  8
# Point   59: ΔLoss =  0.0053,  ΔLoss_tilde =  0.0053, Influence =   0.00648, Steps =  8
# Point   60: ΔLoss = -0.0732,  ΔLoss_tilde = -0.0733, Influence =  -0.03829, Steps =  8
# Point   61: ΔLoss =  0.0544,  ΔLoss_tilde =  0.0549, Influence =   0.01410, Steps =  8
# Point   62: ΔLoss =  0.0098,  ΔLoss_tilde =  0.0096, Influence =   0.00515, Steps =  8
# Point   63: ΔLoss = -0.0284,  ΔLoss_tilde = -0.0284, Influence =  -0.02246, Steps =  8
# Point   64: ΔLoss = -0.0485,  ΔLoss_tilde = -0.0485, Influence =  -0.01374, Steps =  8
# Point   65: ΔLoss = -0.1138,  ΔLoss_tilde = -0.1155, Influence =  -0.03339, Steps =  8
# Point   66: ΔLoss =  0.0063,  ΔLoss_tilde =  0.0061, Influence =   0.00306, Steps =  8
# Point   67: ΔLoss =  0.2131,  ΔLoss_tilde =  0.2133, Influence =   0.05896, Steps =  8
# Point   68: ΔLoss = -0.0257,  ΔLoss_tilde = -0.0259, Influence =  -0.01569, Steps =  8
# Point   69: ΔLoss = -0.0111,  ΔLoss_tilde = -0.0110, Influence =  -0.00783, Steps =  8
# Point   70: ΔLoss =  0.0705,  ΔLoss_tilde =  0.0705, Influence =   0.02550, Steps =  8
# Point   71: ΔLoss = -0.0274,  ΔLoss_tilde = -0.0276, Influence =  -0.00831, Steps =  8
# Point   72: ΔLoss = -0.0991,  ΔLoss_tilde = -0.0996, Influence =  -0.04150, Steps =  8
# Point   73: ΔLoss =  0.0183,  ΔLoss_tilde =  0.0187, Influence =   0.00821, Steps =  8
# Point   74: ΔLoss =  0.0155,  ΔLoss_tilde =  0.0155, Influence =   0.01800, Steps =  8
# Point   75: ΔLoss = -0.0037,  ΔLoss_tilde = -0.0038, Influence =  -0.00254, Steps =  8
# Point   76: ΔLoss =  0.0988,  ΔLoss_tilde =  0.0992, Influence =   0.03269, Steps =  8
# Point   77: ΔLoss =  0.0498,  ΔLoss_tilde =  0.0498, Influence =   0.01802, Steps =  8
# Point   78: ΔLoss =  0.0563,  ΔLoss_tilde =  0.0564, Influence =   0.03999, Steps =  8
# Point   79: ΔLoss =  0.0947,  ΔLoss_tilde =  0.0950, Influence =   0.03169, Steps =  8
# Point   80: ΔLoss = -0.0056,  ΔLoss_tilde = -0.0055, Influence =  -0.00297, Steps =  8
# Point   81: ΔLoss = -0.0617,  ΔLoss_tilde = -0.0620, Influence =  -0.01703, Steps =  8
# Point   82: ΔLoss =  0.0101,  ΔLoss_tilde =  0.0102, Influence =   0.00480, Steps =  8
# Point   83: ΔLoss =  0.0005,  ΔLoss_tilde =  0.0005, Influence =   0.00044, Steps =  8
# Point   84: ΔLoss =  0.0249,  ΔLoss_tilde =  0.0248, Influence =   0.01357, Steps =  8
# Point   85: ΔLoss =  0.0384,  ΔLoss_tilde =  0.0362, Influence =   0.01110, Steps =  8
# Point   86: ΔLoss = -0.0768,  ΔLoss_tilde = -0.0766, Influence =  -0.03079, Steps =  8
# Point   87: ΔLoss =  0.0492,  ΔLoss_tilde =  0.0491, Influence =   0.01592, Steps =  8
# Point   88: ΔLoss =  0.0027,  ΔLoss_tilde =  0.0027, Influence =   0.00292, Steps =  8
# Point   89: ΔLoss =  0.0190,  ΔLoss_tilde =  0.0189, Influence =   0.00895, Steps =  8
# Point   90: ΔLoss = -0.0122,  ΔLoss_tilde = -0.0122, Influence =  -0.00864, Steps =  8
# Point   91: ΔLoss =  0.0502,  ΔLoss_tilde =  0.0502, Influence =   0.01465, Steps =  8
# Point   92: ΔLoss =  0.0380,  ΔLoss_tilde =  0.0379, Influence =   0.01688, Steps =  8
# Point   93: ΔLoss = -0.0375,  ΔLoss_tilde = -0.0376, Influence =  -0.02784, Steps =  8
# Point   94: ΔLoss = -0.0328,  ΔLoss_tilde = -0.0328, Influence =  -0.02161, Steps =  8
# Point   95: ΔLoss = -0.0057,  ΔLoss_tilde = -0.0057, Influence =  -0.00554, Steps =  8
# Point   96: ΔLoss = -0.0264,  ΔLoss_tilde = -0.0262, Influence =  -0.01440, Steps =  8
# Point   97: ΔLoss =  0.1610,  ΔLoss_tilde =  0.1609, Influence =   0.04539, Steps =  8
# Point   98: ΔLoss = -0.0681,  ΔLoss_tilde = -0.0678, Influence =  -0.02931, Steps =  8
# Point   99: ΔLoss = -0.1047,  ΔLoss_tilde = -0.1043, Influence =  -0.04250, Steps =  8
# Point  100: ΔLoss = -0.0760,  ΔLoss_tilde = -0.0758, Influence =  -0.03680, Steps =  8
# Point  101: ΔLoss =  0.0096,  ΔLoss_tilde =  0.0091, Influence =   0.00312, Steps =  8
# Point  102: ΔLoss = -0.0050,  ΔLoss_tilde = -0.0062, Influence =  -0.00136, Steps =  8
# Point  103: ΔLoss =  0.0387,  ΔLoss_tilde =  0.0386, Influence =   0.01873, Steps =  8
# Point  104: ΔLoss = -0.0161,  ΔLoss_tilde = -0.0161, Influence =  -0.01129, Steps =  8
# Point  105: ΔLoss = -0.0312,  ΔLoss_tilde = -0.0312, Influence =  -0.01300, Steps =  8
# Point  106: ΔLoss = -0.0158,  ΔLoss_tilde = -0.0158, Influence =  -0.01556, Steps =  8
# Point  107: ΔLoss = -0.0073,  ΔLoss_tilde = -0.0068, Influence =  -0.00261, Steps =  8
# Point  108: ΔLoss = -0.0413,  ΔLoss_tilde = -0.0412, Influence =  -0.02276, Steps =  8
# Point  109: ΔLoss =  0.0376,  ΔLoss_tilde =  0.0372, Influence =   0.01306, Steps =  8
# Point  110: ΔLoss =  0.0021,  ΔLoss_tilde =  0.0014, Influence =   0.00046, Steps =  8
# Point  111: ΔLoss =  0.0075,  ΔLoss_tilde =  0.0075, Influence =   0.01062, Steps =  8
# Point  112: ΔLoss = -0.0090,  ΔLoss_tilde = -0.0100, Influence =  -0.00255, Steps =  8
# Point  113: ΔLoss = -0.0143,  ΔLoss_tilde = -0.0143, Influence =  -0.01233, Steps =  8
# Point  114: ΔLoss =  0.0002,  ΔLoss_tilde =  0.0001, Influence =   0.00008, Steps =  8
# Point  115: ΔLoss =  0.0185,  ΔLoss_tilde =  0.0184, Influence =   0.01011, Steps =  8
# Point  116: ΔLoss =  0.0311,  ΔLoss_tilde =  0.0310, Influence =   0.01648, Steps =  8
# Point  117: ΔLoss = -0.1031,  ΔLoss_tilde = -0.1030, Influence =  -0.03805, Steps =  8
# Point  118: ΔLoss =  0.0068,  ΔLoss_tilde =  0.0068, Influence =   0.00612, Steps =  8
# Point  119: ΔLoss =  0.0518,  ΔLoss_tilde =  0.0510, Influence =   0.01399, Steps =  8
# Point  120: ΔLoss = -0.0015,  ΔLoss_tilde = -0.0015, Influence =  -0.00073, Steps =  8
# Point  121: ΔLoss =  0.0652,  ΔLoss_tilde =  0.0649, Influence =   0.02249, Steps =  8
# Point  122: ΔLoss =  0.0046,  ΔLoss_tilde =  0.0046, Influence =   0.00470, Steps =  8
# Point  123: ΔLoss = -0.0232,  ΔLoss_tilde = -0.0231, Influence =  -0.01413, Steps =  8
# Point  124: ΔLoss =  0.0168,  ΔLoss_tilde =  0.0169, Influence =   0.01170, Steps =  8
# Point  125: ΔLoss =  0.0022,  ΔLoss_tilde =  0.0022, Influence =   0.00179, Steps =  8
# Point  126: ΔLoss = -0.0285,  ΔLoss_tilde = -0.0280, Influence =  -0.01159, Steps =  8
# Point  127: ΔLoss =  0.0396,  ΔLoss_tilde =  0.0388, Influence =   0.01330, Steps =  8
# Point  128: ΔLoss = -0.0963,  ΔLoss_tilde = -0.0957, Influence =  -0.04098, Steps =  8
# Point  129: ΔLoss = -0.0006,  ΔLoss_tilde = -0.0006, Influence =  -0.00113, Steps =  8
# Point  130: ΔLoss = -0.0004,  ΔLoss_tilde = -0.0004, Influence =  -0.00072, Steps =  8
# Point  131: ΔLoss = -0.0178,  ΔLoss_tilde = -0.0177, Influence =  -0.01332, Steps =  8
# Point  132: ΔLoss =  0.0155,  ΔLoss_tilde =  0.0154, Influence =   0.01417, Steps =  8
# Point  133: ΔLoss =  0.0055,  ΔLoss_tilde =  0.0059, Influence =   0.00164, Steps =  8
# Point  134: ΔLoss =  0.0440,  ΔLoss_tilde =  0.0442, Influence =   0.00959, Steps =  8
# Point  135: ΔLoss = -0.0379,  ΔLoss_tilde = -0.0380, Influence =  -0.02632, Steps =  8
# Point  136: ΔLoss = -0.0588,  ΔLoss_tilde = -0.0589, Influence =  -0.02478, Steps =  8
# Point  137: ΔLoss = -0.1644,  ΔLoss_tilde = -0.1645, Influence =  -0.05734, Steps =  8
# Point  138: ΔLoss = -0.0017,  ΔLoss_tilde = -0.0017, Influence =  -0.00300, Steps =  8
# Point  139: ΔLoss = -0.0132,  ΔLoss_tilde = -0.0132, Influence =  -0.01099, Steps =  8
# Point  140: ΔLoss =  0.0034,  ΔLoss_tilde =  0.0034, Influence =   0.00516, Steps =  8
# Point  141: ΔLoss = -0.0061,  ΔLoss_tilde = -0.0062, Influence =  -0.00258, Steps =  8
# Point  142: ΔLoss =  0.0093,  ΔLoss_tilde =  0.0089, Influence =   0.00374, Steps =  8
# Point  143: ΔLoss = -0.0075,  ΔLoss_tilde = -0.0075, Influence =  -0.00986, Steps =  8
# Point  144: ΔLoss =  0.0057,  ΔLoss_tilde =  0.0063, Influence =   0.00247, Steps =  8
# Point  145: ΔLoss = -0.0225,  ΔLoss_tilde = -0.0233, Influence =  -0.00742, Steps =  8
# Point  146: ΔLoss = -0.0111,  ΔLoss_tilde = -0.0114, Influence =  -0.00576, Steps =  8
# Point  147: ΔLoss =  0.1185,  ΔLoss_tilde =  0.1185, Influence =   0.05098, Steps =  8
# Point  148: ΔLoss = -0.0122,  ΔLoss_tilde = -0.0122, Influence =  -0.00880, Steps =  8
# Point  149: ΔLoss =  0.0494,  ΔLoss_tilde =  0.0492, Influence =   0.02908, Steps =  8
# Point  150: ΔLoss = -0.0455,  ΔLoss_tilde = -0.0455, Influence =  -0.02035, Steps =  8
# Point  151: ΔLoss =  0.0697,  ΔLoss_tilde =  0.0695, Influence =   0.01923, Steps =  8
# Point  152: ΔLoss =  0.0367,  ΔLoss_tilde =  0.0365, Influence =   0.01329, Steps =  8
# Point  153: ΔLoss = -0.0249,  ΔLoss_tilde = -0.0249, Influence =  -0.01532, Steps =  8
# Point  154: ΔLoss =  0.0337,  ΔLoss_tilde =  0.0332, Influence =   0.01062, Steps =  8
# Point  155: ΔLoss =  0.0013,  ΔLoss_tilde =  0.0013, Influence =   0.00207, Steps =  8
# Point  156: ΔLoss =  0.0945,  ΔLoss_tilde =  0.0943, Influence =   0.03920, Steps =  8
# Point  157: ΔLoss = -0.0864,  ΔLoss_tilde = -0.0862, Influence =  -0.04391, Steps =  8
# Point  158: ΔLoss = -0.0252,  ΔLoss_tilde = -0.0252, Influence =  -0.02549, Steps =  8
# Point  159: ΔLoss = -0.0730,  ΔLoss_tilde = -0.0732, Influence =  -0.04006, Steps =  8
# Point  160: ΔLoss = -0.0241,  ΔLoss_tilde = -0.0243, Influence =  -0.00943, Steps =  8
# Point  161: ΔLoss = -0.0047,  ΔLoss_tilde = -0.0048, Influence =  -0.00364, Steps =  8
# Point  162: ΔLoss = -0.0034,  ΔLoss_tilde = -0.0034, Influence =  -0.00327, Steps =  8
# Point  163: ΔLoss =  0.0942,  ΔLoss_tilde =  0.0946, Influence =   0.03346, Steps =  8
# Point  164: ΔLoss = -0.0140,  ΔLoss_tilde = -0.0139, Influence =  -0.00855, Steps =  8
# Point  165: ΔLoss = -0.0439,  ΔLoss_tilde = -0.0431, Influence =  -0.01245, Steps =  8
# Point  166: ΔLoss = -0.0330,  ΔLoss_tilde = -0.0332, Influence =  -0.01168, Steps =  8
# Point  167: ΔLoss =  0.1025,  ΔLoss_tilde =  0.1020, Influence =   0.02882, Steps =  8
# Point  168: ΔLoss =  0.0636,  ΔLoss_tilde =  0.0639, Influence =   0.02115, Steps =  8
# Point  169: ΔLoss =  0.0383,  ΔLoss_tilde =  0.0383, Influence =   0.03359, Steps =  8
# Point  170: ΔLoss = -0.0047,  ΔLoss_tilde = -0.0047, Influence =  -0.00543, Steps =  8
# Point  171: ΔLoss = -0.0469,  ΔLoss_tilde = -0.0475, Influence =  -0.01899, Steps =  8
# Point  172: ΔLoss = -0.0383,  ΔLoss_tilde = -0.0382, Influence =  -0.01191, Steps =  8
# Point  173: ΔLoss = -0.0004,  ΔLoss_tilde = -0.0005, Influence =  -0.00029, Steps =  8
# Point  174: ΔLoss = -0.0007,  ΔLoss_tilde = -0.0007, Influence =  -0.00121, Steps =  8
# Point  175: ΔLoss =  0.0321,  ΔLoss_tilde =  0.0322, Influence =   0.01982, Steps =  8
# Point  176: ΔLoss = -0.0150,  ΔLoss_tilde = -0.0151, Influence =  -0.00845, Steps =  8
# Point  177: ΔLoss = -0.0184,  ΔLoss_tilde = -0.0184, Influence =  -0.01582, Steps =  8
# Point  178: ΔLoss = -0.0396,  ΔLoss_tilde = -0.0397, Influence =  -0.03050, Steps =  8
# Point  179: ΔLoss =  0.0009,  ΔLoss_tilde =  0.0009, Influence =   0.00154, Steps =  8
# Point  180: ΔLoss =  0.0337,  ΔLoss_tilde =  0.0332, Influence =   0.01236, Steps =  8
# Point  181: ΔLoss =  0.0277,  ΔLoss_tilde =  0.0273, Influence =   0.01118, Steps =  8
# Point  182: ΔLoss = -0.0463,  ΔLoss_tilde = -0.0463, Influence =  -0.01807, Steps =  8
# Point  183: ΔLoss =  0.0220,  ΔLoss_tilde =  0.0220, Influence =   0.01751, Steps =  8
# Point  184: ΔLoss = -0.0059,  ΔLoss_tilde = -0.0059, Influence =  -0.00690, Steps =  8
# Point  185: ΔLoss = -0.0555,  ΔLoss_tilde = -0.0556, Influence =  -0.04204, Steps =  8
# Point  186: ΔLoss = -0.0030,  ΔLoss_tilde = -0.0033, Influence =  -0.00098, Steps =  8
# Point  187: ΔLoss = -0.0009,  ΔLoss_tilde = -0.0009, Influence =  -0.00070, Steps =  8
# Point  188: ΔLoss = -0.0394,  ΔLoss_tilde = -0.0395, Influence =  -0.02647, Steps =  8
# Point  189: ΔLoss = -0.0245,  ΔLoss_tilde = -0.0248, Influence =  -0.01458, Steps =  8
# Point  190: ΔLoss =  0.0666,  ΔLoss_tilde =  0.0665, Influence =   0.02517, Steps =  8
# Point  191: ΔLoss = -0.0066,  ΔLoss_tilde = -0.0067, Influence =  -0.00486, Steps =  8
# Point  192: ΔLoss = -0.0804,  ΔLoss_tilde = -0.0804, Influence =  -0.04253, Steps =  8
# Point  193: ΔLoss = -0.0061,  ΔLoss_tilde = -0.0063, Influence =  -0.00191, Steps =  8
# Point  194: ΔLoss = -0.0533,  ΔLoss_tilde = -0.0529, Influence =  -0.01767, Steps =  8
# Point  195: ΔLoss = -0.0099,  ΔLoss_tilde = -0.0096, Influence =  -0.00567, Steps =  8
# Point  196: ΔLoss =  0.0486,  ΔLoss_tilde =  0.0483, Influence =   0.02461, Steps =  8
# Point  197: ΔLoss =  0.0116,  ΔLoss_tilde =  0.0116, Influence =   0.01165, Steps =  8
# Point  198: ΔLoss = -0.0287,  ΔLoss_tilde = -0.0292, Influence =  -0.01258, Steps =  8
# Point  199: ΔLoss =  0.0259,  ΔLoss_tilde =  0.0259, Influence =   0.01715, Steps =  8
# Point  200: ΔLoss = -0.1264,  ΔLoss_tilde = -0.1262, Influence =  -0.04144, Steps =  8
# Point  201: ΔLoss =  0.0031,  ΔLoss_tilde =  0.0031, Influence =   0.00379, Steps =  8
# Point  202: ΔLoss =  0.0452,  ΔLoss_tilde =  0.0449, Influence =   0.02133, Steps =  8
# Point  203: ΔLoss = -0.0070,  ΔLoss_tilde = -0.0070, Influence =  -0.00596, Steps =  8
# Point  204: ΔLoss =  0.0260,  ΔLoss_tilde =  0.0255, Influence =   0.00734, Steps =  8
# Point  205: ΔLoss =  0.1361,  ΔLoss_tilde =  0.1363, Influence =   0.04053, Steps =  8
# Point  206: ΔLoss = -0.1236,  ΔLoss_tilde = -0.1232, Influence =  -0.04237, Steps =  8
# Point  207: ΔLoss =  0.0459,  ΔLoss_tilde =  0.0461, Influence =   0.02261, Steps =  8
# Point  208: ΔLoss = -0.0144,  ΔLoss_tilde = -0.0144, Influence =  -0.01560, Steps =  8
# Point  209: ΔLoss =  0.0442,  ΔLoss_tilde =  0.0443, Influence =   0.01359, Steps =  8
# Point  210: ΔLoss = -0.0073,  ΔLoss_tilde = -0.0074, Influence =  -0.00328, Steps =  8
# Point  211: ΔLoss =  0.0095,  ΔLoss_tilde =  0.0095, Influence =   0.01161, Steps =  8
# Point  212: ΔLoss = -0.0453,  ΔLoss_tilde = -0.0453, Influence =  -0.01880, Steps =  8
# Point  213: ΔLoss = -0.0121,  ΔLoss_tilde = -0.0121, Influence =  -0.01097, Steps =  8
# Point  214: ΔLoss = -0.0540,  ΔLoss_tilde = -0.0547, Influence =  -0.02201, Steps =  8
# Point  215: ΔLoss =  0.0151,  ΔLoss_tilde =  0.0151, Influence =   0.01588, Steps =  8
# Point  216: ΔLoss =  0.0434,  ΔLoss_tilde =  0.0437, Influence =   0.01277, Steps =  8
# Point  217: ΔLoss =  0.0541,  ΔLoss_tilde =  0.0541, Influence =   0.03998, Steps =  8
# Point  218: ΔLoss =  0.0092,  ΔLoss_tilde =  0.0092, Influence =   0.01259, Steps =  8
# Point  219: ΔLoss =  0.0533,  ΔLoss_tilde =  0.0531, Influence =   0.01904, Steps =  8
# Point  220: ΔLoss =  0.0643,  ΔLoss_tilde =  0.0644, Influence =   0.02234, Steps =  8
# Point  221: ΔLoss =  0.2172,  ΔLoss_tilde =  0.2199, Influence =   0.03841, Steps =  8
# Point  222: ΔLoss = -0.0664,  ΔLoss_tilde = -0.0665, Influence =  -0.02793, Steps =  8
# Point  223: ΔLoss =  0.0380,  ΔLoss_tilde =  0.0380, Influence =   0.01841, Steps =  8
# Point  224: ΔLoss = -0.0130,  ΔLoss_tilde = -0.0127, Influence =  -0.00568, Steps =  8
# Point  225: ΔLoss =  0.0507,  ΔLoss_tilde =  0.0506, Influence =   0.02055, Steps =  8
# Point  226: ΔLoss = -0.0178,  ΔLoss_tilde = -0.0179, Influence =  -0.01483, Steps =  8
# Point  227: ΔLoss =  0.0850,  ΔLoss_tilde =  0.0845, Influence =   0.03905, Steps =  8
# Point  228: ΔLoss = -0.0204,  ΔLoss_tilde = -0.0204, Influence =  -0.01238, Steps =  8
# Point  229: ΔLoss =  0.0526,  ΔLoss_tilde =  0.0528, Influence =   0.01797, Steps =  8
# Point  230: ΔLoss = -0.0022,  ΔLoss_tilde = -0.0022, Influence =  -0.00165, Steps =  8
# Point  231: ΔLoss = -0.0188,  ΔLoss_tilde = -0.0189, Influence =  -0.01302, Steps =  8
# Point  232: ΔLoss = -0.0625,  ΔLoss_tilde = -0.0626, Influence =  -0.03946, Steps =  8
# Point  233: ΔLoss =  0.0103,  ΔLoss_tilde =  0.0103, Influence =   0.00807, Steps =  8
# Point  234: ΔLoss = -0.0132,  ΔLoss_tilde = -0.0132, Influence =  -0.01316, Steps =  8
# Point  235: ΔLoss = -0.1078,  ΔLoss_tilde = -0.1086, Influence =  -0.04265, Steps =  8
# Point  236: ΔLoss = -0.0980,  ΔLoss_tilde = -0.0988, Influence =  -0.03368, Steps =  8
# Point  237: ΔLoss = -0.0617,  ΔLoss_tilde = -0.0616, Influence =  -0.02379, Steps =  8
# Point  238: ΔLoss = -0.0086,  ΔLoss_tilde = -0.0086, Influence =  -0.01070, Steps =  8
# Point  239: ΔLoss =  0.0190,  ΔLoss_tilde =  0.0193, Influence =   0.00891, Steps =  8
# Point  240: ΔLoss =  0.0051,  ΔLoss_tilde =  0.0052, Influence =   0.00264, Steps =  8
# Point  241: ΔLoss = -0.0595,  ΔLoss_tilde = -0.0592, Influence =  -0.02192, Steps =  8
# Point  242: ΔLoss = -0.0067,  ΔLoss_tilde = -0.0067, Influence =  -0.00528, Steps =  8
# Point  243: ΔLoss = -0.0874,  ΔLoss_tilde = -0.0875, Influence =  -0.04977, Steps =  8
# Point  244: ΔLoss = -0.0335,  ΔLoss_tilde = -0.0338, Influence =  -0.01747, Steps =  8
# Point  245: ΔLoss = -0.0112,  ΔLoss_tilde = -0.0113, Influence =  -0.00751, Steps =  8
# Point  246: ΔLoss = -0.0591,  ΔLoss_tilde = -0.0593, Influence =  -0.02606, Steps =  8
# Point  247: ΔLoss = -0.0186,  ΔLoss_tilde = -0.0185, Influence =  -0.00822, Steps =  8
# Point  248: ΔLoss = -0.0348,  ΔLoss_tilde = -0.0348, Influence =  -0.01802, Steps =  8
# Point  249: ΔLoss =  0.0243,  ΔLoss_tilde =  0.0248, Influence =   0.00989, Steps =  8
# Point  250: ΔLoss = -0.0268,  ΔLoss_tilde = -0.0275, Influence =  -0.00643, Steps =  8
# Point  251: ΔLoss = -0.0224,  ΔLoss_tilde = -0.0226, Influence =  -0.00958, Steps =  8
# Point  252: ΔLoss = -0.0929,  ΔLoss_tilde = -0.0929, Influence =  -0.03835, Steps =  8
# Point  253: ΔLoss = -0.0195,  ΔLoss_tilde = -0.0194, Influence =  -0.01219, Steps =  8
# Point  254: ΔLoss = -0.0891,  ΔLoss_tilde = -0.0885, Influence =  -0.02391, Steps =  8
# Point  255: ΔLoss =  0.0175,  ΔLoss_tilde =  0.0175, Influence =   0.01360, Steps =  8
# Point  256: ΔLoss =  0.0169,  ΔLoss_tilde =  0.0161, Influence =   0.00455, Steps =  8
# Point  257: ΔLoss = -0.0172,  ΔLoss_tilde = -0.0172, Influence =  -0.02232, Steps =  8
# Point  258: ΔLoss =  0.0012,  ΔLoss_tilde =  0.0013, Influence =   0.00074, Steps =  8
# Point  259: ΔLoss =  0.0481,  ΔLoss_tilde =  0.0479, Influence =   0.01872, Steps =  8
# Point  260: ΔLoss = -0.0627,  ΔLoss_tilde = -0.0653, Influence =  -0.01694, Steps =  8
# Point  261: ΔLoss =  0.0076,  ΔLoss_tilde =  0.0078, Influence =   0.00398, Steps =  8
# Point  262: ΔLoss =  0.0061,  ΔLoss_tilde =  0.0061, Influence =   0.00848, Steps =  8
# Point  263: ΔLoss = -0.0067,  ΔLoss_tilde = -0.0067, Influence =  -0.00928, Steps =  8
# Point  264: ΔLoss =  0.0139,  ΔLoss_tilde =  0.0141, Influence =   0.00492, Steps =  8
# Point  265: ΔLoss = -0.0982,  ΔLoss_tilde = -0.0983, Influence =  -0.03272, Steps =  8
# Point  266: ΔLoss =  0.0584,  ΔLoss_tilde =  0.0584, Influence =   0.02086, Steps =  8
# Point  267: ΔLoss =  0.0402,  ΔLoss_tilde =  0.0403, Influence =   0.01347, Steps =  8
# Point  268: ΔLoss = -0.0202,  ΔLoss_tilde = -0.0203, Influence =  -0.01127, Steps =  8
# Point  269: ΔLoss =  0.1123,  ΔLoss_tilde =  0.1129, Influence =   0.03984, Steps =  8
# Point  270: ΔLoss =  0.0199,  ΔLoss_tilde =  0.0199, Influence =   0.01583, Steps =  8
# Point  271: ΔLoss = -0.0267,  ΔLoss_tilde = -0.0268, Influence =  -0.01197, Steps =  8
# Point  272: ΔLoss = -0.0319,  ΔLoss_tilde = -0.0282, Influence =  -0.00568, Steps =  8
# Point  273: ΔLoss = -0.1186,  ΔLoss_tilde = -0.1173, Influence =  -0.02958, Steps =  8
# Point  274: ΔLoss = -0.0561,  ΔLoss_tilde = -0.0563, Influence =  -0.03291, Steps =  8
# Point  275: ΔLoss = -0.0229,  ΔLoss_tilde = -0.0232, Influence =  -0.01100, Steps =  8
# Point  276: ΔLoss = -0.0161,  ΔLoss_tilde = -0.0160, Influence =  -0.00685, Steps =  8
# Point  277: ΔLoss =  0.0313,  ΔLoss_tilde =  0.0314, Influence =   0.01467, Steps =  8
# Point  278: ΔLoss =  0.0589,  ΔLoss_tilde =  0.0585, Influence =   0.02148, Steps =  8
# Point  279: ΔLoss = -0.0305,  ΔLoss_tilde = -0.0307, Influence =  -0.01304, Steps =  8
# Point  280: ΔLoss = -0.0641,  ΔLoss_tilde = -0.0631, Influence =  -0.01816, Steps =  8
# Point  281: ΔLoss = -0.0016,  ΔLoss_tilde = -0.0014, Influence =  -0.00096, Steps =  8
# Point  282: ΔLoss = -0.0009,  ΔLoss_tilde = -0.0009, Influence =  -0.00146, Steps =  8
# Point  283: ΔLoss =  0.0126,  ΔLoss_tilde =  0.0125, Influence =   0.00539, Steps =  8
# Point  284: ΔLoss = -0.0910,  ΔLoss_tilde = -0.0903, Influence =  -0.03187, Steps =  8
# Point  285: ΔLoss =  0.0344,  ΔLoss_tilde =  0.0341, Influence =   0.01520, Steps =  8
# Point  286: ΔLoss = -0.0269,  ΔLoss_tilde = -0.0263, Influence =  -0.00974, Steps =  8
# Point  287: ΔLoss =  0.0850,  ΔLoss_tilde =  0.0849, Influence =   0.02486, Steps =  8
# Point  288: ΔLoss = -0.0387,  ΔLoss_tilde = -0.0386, Influence =  -0.02080, Steps =  8
# Point  289: ΔLoss = -0.0484,  ΔLoss_tilde = -0.0484, Influence =  -0.03687, Steps =  8
# Point  290: ΔLoss = -0.0053,  ΔLoss_tilde = -0.0052, Influence =  -0.00264, Steps =  8
# Point  291: ΔLoss = -0.0014,  ΔLoss_tilde = -0.0014, Influence =  -0.00175, Steps =  8
# Point  292: ΔLoss =  0.1008,  ΔLoss_tilde =  0.1007, Influence =   0.03435, Steps =  8
# Point  293: ΔLoss =  0.0018,  ΔLoss_tilde =  0.0018, Influence =   0.00251, Steps =  8
# Point  294: ΔLoss =  0.1656,  ΔLoss_tilde =  0.1664, Influence =   0.03132, Steps =  8
# Point  295: ΔLoss = -0.0114,  ΔLoss_tilde = -0.0114, Influence =  -0.01286, Steps =  8
# Point  296: ΔLoss = -0.0448,  ΔLoss_tilde = -0.0449, Influence =  -0.01723, Steps =  8
# Point  297: ΔLoss =  0.0761,  ΔLoss_tilde =  0.0759, Influence =   0.02421, Steps =  8
# Point  298: ΔLoss =  0.0003,  ΔLoss_tilde =  0.0003, Influence =   0.00063, Steps =  8
# Point  299: ΔLoss =  0.0517,  ΔLoss_tilde =  0.0513, Influence =   0.01520, Steps =  8
# Point  300: ΔLoss =  0.0175,  ΔLoss_tilde =  0.0175, Influence =   0.01945, Steps =  8
# Point  301: ΔLoss =  0.0669,  ΔLoss_tilde =  0.0671, Influence =   0.03513, Steps =  8
# Point  302: ΔLoss = -0.0031,  ΔLoss_tilde = -0.0031, Influence =  -0.00515, Steps =  8
# Point  303: ΔLoss =  0.0069,  ΔLoss_tilde =  0.0069, Influence =   0.00780, Steps =  8
# Point  304: ΔLoss =  0.0782,  ΔLoss_tilde =  0.0782, Influence =   0.03386, Steps =  8
# Point  305: ΔLoss =  0.0081,  ΔLoss_tilde =  0.0076, Influence =   0.00185, Steps =  8
# Point  306: ΔLoss =  0.0103,  ΔLoss_tilde =  0.0103, Influence =   0.01093, Steps =  8
# Point  307: ΔLoss = -0.0287,  ΔLoss_tilde = -0.0287, Influence =  -0.01263, Steps =  8
# Point  308: ΔLoss =  0.1528,  ΔLoss_tilde =  0.1508, Influence =   0.03489, Steps =  8
# Point  309: ΔLoss =  0.0526,  ΔLoss_tilde =  0.0530, Influence =   0.02217, Steps =  8
# Point  310: ΔLoss = -0.0991,  ΔLoss_tilde = -0.0998, Influence =  -0.03393, Steps =  8
# Point  311: ΔLoss =  0.1124,  ΔLoss_tilde =  0.1128, Influence =   0.04891, Steps =  8
# Point  312: ΔLoss = -0.0200,  ΔLoss_tilde = -0.0201, Influence =  -0.01407, Steps =  8
# Point  313: ΔLoss =  0.0332,  ΔLoss_tilde =  0.0331, Influence =   0.02803, Steps =  8
# Point  314: ΔLoss =  0.0198,  ΔLoss_tilde =  0.0202, Influence =   0.00681, Steps =  8
# Point  315: ΔLoss = -0.0152,  ΔLoss_tilde = -0.0131, Influence =  -0.00324, Steps =  8
# Point  316: ΔLoss =  0.0198,  ΔLoss_tilde =  0.0197, Influence =   0.01479, Steps =  8
# Point  317: ΔLoss =  0.0503,  ΔLoss_tilde =  0.0506, Influence =   0.02527, Steps =  8
# Point  318: ΔLoss = -0.0601,  ΔLoss_tilde = -0.0600, Influence =  -0.02697, Steps =  8
# Point  319: ΔLoss =  0.0793,  ΔLoss_tilde =  0.0794, Influence =   0.02356, Steps =  8
# Point  320: ΔLoss =  0.0024,  ΔLoss_tilde =  0.0024, Influence =   0.00162, Steps =  8
# Point  321: ΔLoss = -0.0046,  ΔLoss_tilde = -0.0046, Influence =  -0.00609, Steps =  8
# Point  322: ΔLoss = -0.0124,  ΔLoss_tilde = -0.0125, Influence =  -0.00752, Steps =  8
# Point  323: ΔLoss = -0.0152,  ΔLoss_tilde = -0.0152, Influence =  -0.01156, Steps =  8
# Point  324: ΔLoss = -0.0481,  ΔLoss_tilde = -0.0483, Influence =  -0.02345, Steps =  8
# Point  325: ΔLoss =  0.0059,  ΔLoss_tilde =  0.0061, Influence =   0.00363, Steps =  8
# Point  326: ΔLoss =  0.0208,  ΔLoss_tilde =  0.0206, Influence =   0.00766, Steps =  8
# Point  327: ΔLoss = -0.0391,  ΔLoss_tilde = -0.0391, Influence =  -0.01894, Steps =  8
# Point  328: ΔLoss = -0.0137,  ΔLoss_tilde = -0.0139, Influence =  -0.00824, Steps =  8
# Point  329: ΔLoss =  0.0027,  ΔLoss_tilde =  0.0025, Influence =   0.00080, Steps =  8
# Point  330: ΔLoss = -0.0192,  ΔLoss_tilde = -0.0192, Influence =  -0.00905, Steps =  8
# Point  331: ΔLoss =  0.0007,  ΔLoss_tilde =  0.0006, Influence =   0.00034, Steps =  8
# Point  332: ΔLoss = -0.0462,  ΔLoss_tilde = -0.0461, Influence =  -0.02707, Steps =  8
# Point  333: ΔLoss = -0.0023,  ΔLoss_tilde = -0.0023, Influence =  -0.00281, Steps =  8
# Point  334: ΔLoss = -0.0071,  ΔLoss_tilde = -0.0073, Influence =  -0.00251, Steps =  8
# Point  335: ΔLoss =  0.0001,  ΔLoss_tilde =  0.0000, Influence =   0.00002, Steps =  8
# Point  336: ΔLoss = -0.0374,  ΔLoss_tilde = -0.0374, Influence =  -0.02129, Steps =  8
# Point  337: ΔLoss = -0.0041,  ΔLoss_tilde = -0.0031, Influence =  -0.00090, Steps =  8
# Point  338: ΔLoss = -0.0052,  ΔLoss_tilde = -0.0052, Influence =  -0.00375, Steps =  8
# Point  339: ΔLoss = -0.0135,  ΔLoss_tilde = -0.0135, Influence =  -0.01131, Steps =  8
# Point  340: ΔLoss =  0.0793,  ΔLoss_tilde =  0.0793, Influence =   0.03775, Steps =  8
# Point  341: ΔLoss = -0.0767,  ΔLoss_tilde = -0.0762, Influence =  -0.02932, Steps =  8
# Point  342: ΔLoss =  0.0112,  ΔLoss_tilde =  0.0110, Influence =   0.00313, Steps =  8
# Point  343: ΔLoss =  0.0240,  ΔLoss_tilde =  0.0241, Influence =   0.01062, Steps =  8
# Point  344: ΔLoss = -0.0358,  ΔLoss_tilde = -0.0358, Influence =  -0.02441, Steps =  8
# Point  345: ΔLoss =  0.0964,  ΔLoss_tilde =  0.0960, Influence =   0.02918, Steps =  8
# Point  346: ΔLoss = -0.0482,  ΔLoss_tilde = -0.0482, Influence =  -0.01772, Steps =  8
# Point  347: ΔLoss =  0.0629,  ΔLoss_tilde =  0.0630, Influence =   0.01834, Steps =  8
# Point  348: ΔLoss =  0.0195,  ΔLoss_tilde =  0.0194, Influence =   0.01268, Steps =  8
# Point  349: ΔLoss = -0.0052,  ΔLoss_tilde = -0.0052, Influence =  -0.00367, Steps =  8
# Point  350: ΔLoss =  0.0060,  ΔLoss_tilde =  0.0061, Influence =   0.00600, Steps =  8
# Point  351: ΔLoss =  0.0967,  ΔLoss_tilde =  0.0965, Influence =   0.03257, Steps =  8
# Point  352: ΔLoss =  0.0724,  ΔLoss_tilde =  0.0725, Influence =   0.03885, Steps =  8
# Point  353: ΔLoss = -0.0714,  ΔLoss_tilde = -0.0714, Influence =  -0.03460, Steps =  8
# Point  354: ΔLoss =  0.0036,  ΔLoss_tilde =  0.0037, Influence =   0.00320, Steps =  8
# Point  355: ΔLoss =  0.0626,  ΔLoss_tilde =  0.0626, Influence =   0.01767, Steps =  8
# Point  356: ΔLoss = -0.0209,  ΔLoss_tilde = -0.0212, Influence =  -0.01015, Steps =  8
# Point  357: ΔLoss = -0.0834,  ΔLoss_tilde = -0.0834, Influence =  -0.02683, Steps =  8
# Point  358: ΔLoss = -0.0257,  ΔLoss_tilde = -0.0278, Influence =  -0.00904, Steps =  8
# Point  359: ΔLoss =  0.2507,  ΔLoss_tilde =  0.2495, Influence =   0.06621, Steps =  8
# Point  360: ΔLoss = -0.0144,  ΔLoss_tilde = -0.0144, Influence =  -0.01321, Steps =  8
# Point  361: ΔLoss = -0.0080,  ΔLoss_tilde = -0.0080, Influence =  -0.00609, Steps =  8
# Point  362: ΔLoss = -0.0227,  ΔLoss_tilde = -0.0226, Influence =  -0.01088, Steps =  8
# Point  363: ΔLoss =  0.1138,  ΔLoss_tilde =  0.1128, Influence =   0.02960, Steps =  8
# Point  364: ΔLoss = -0.0425,  ΔLoss_tilde = -0.0425, Influence =  -0.01453, Steps =  8
# Point  365: ΔLoss = -0.1473,  ΔLoss_tilde = -0.1476, Influence =  -0.06125, Steps =  8
# Point  366: ΔLoss =  0.0202,  ΔLoss_tilde =  0.0202, Influence =   0.00954, Steps =  8
# Point  367: ΔLoss = -0.0806,  ΔLoss_tilde = -0.0806, Influence =  -0.04237, Steps =  8
# Point  368: ΔLoss =  0.0572,  ΔLoss_tilde =  0.0564, Influence =   0.01689, Steps =  8
# Point  369: ΔLoss =  0.0534,  ΔLoss_tilde =  0.0533, Influence =   0.02699, Steps =  8
# Point  370: ΔLoss =  0.0220,  ΔLoss_tilde =  0.0215, Influence =   0.00738, Steps =  8
# Point  371: ΔLoss =  0.0369,  ΔLoss_tilde =  0.0370, Influence =   0.01700, Steps =  8
# Point  372: ΔLoss = -0.0066,  ΔLoss_tilde = -0.0069, Influence =  -0.00231, Steps =  8
# Point  373: ΔLoss =  0.0117,  ΔLoss_tilde =  0.0117, Influence =   0.00875, Steps =  8
# Point  374: ΔLoss =  0.0089,  ΔLoss_tilde =  0.0087, Influence =   0.00599, Steps =  8
# Point  375: ΔLoss = -0.0025,  ΔLoss_tilde = -0.0025, Influence =  -0.00214, Steps =  8
# Point  376: ΔLoss =  0.1000,  ΔLoss_tilde =  0.0999, Influence =   0.04569, Steps =  8
# Point  377: ΔLoss =  0.0775,  ΔLoss_tilde =  0.0774, Influence =   0.03551, Steps =  8
# Point  378: ΔLoss =  0.0049,  ΔLoss_tilde =  0.0049, Influence =   0.00679, Steps =  8
# Point  379: ΔLoss =  0.0449,  ΔLoss_tilde =  0.0449, Influence =   0.02523, Steps =  8
# Point  380: ΔLoss = -0.0300,  ΔLoss_tilde = -0.0299, Influence =  -0.02208, Steps =  8
# Point  381: ΔLoss = -0.0034,  ΔLoss_tilde = -0.0034, Influence =  -0.00537, Steps =  8
# Point  382: ΔLoss = -0.0310,  ΔLoss_tilde = -0.0306, Influence =  -0.01313, Steps =  8
# Point  383: ΔLoss = -0.0603,  ΔLoss_tilde = -0.0597, Influence =  -0.02124, Steps =  8
# Point  384: ΔLoss =  0.0098,  ΔLoss_tilde =  0.0098, Influence =   0.01311, Steps =  8
# Point  385: ΔLoss =  0.1388,  ΔLoss_tilde =  0.1342, Influence =   0.02817, Steps =  8
# Point  386: ΔLoss =  0.0032,  ΔLoss_tilde =  0.0032, Influence =   0.00370, Steps =  8
# Point  387: ΔLoss =  0.0095,  ΔLoss_tilde =  0.0095, Influence =   0.00988, Steps =  8
# Point  388: ΔLoss =  0.0032,  ΔLoss_tilde =  0.0032, Influence =   0.00506, Steps =  8
# Point  389: ΔLoss =  0.0670,  ΔLoss_tilde =  0.0668, Influence =   0.02555, Steps =  8
# Point  390: ΔLoss =  0.0150,  ΔLoss_tilde =  0.0147, Influence =   0.00501, Steps =  8
# Point  391: ΔLoss = -0.1121,  ΔLoss_tilde = -0.1122, Influence =  -0.04804, Steps =  8
# Point  392: ΔLoss = -0.0398,  ΔLoss_tilde = -0.0399, Influence =  -0.02920, Steps =  8
# Point  393: ΔLoss =  0.0137,  ΔLoss_tilde =  0.0137, Influence =   0.01291, Steps =  8
# Point  394: ΔLoss = -0.0839,  ΔLoss_tilde = -0.0838, Influence =  -0.03988, Steps =  8
# Point  395: ΔLoss = -0.0001,  ΔLoss_tilde = -0.0001, Influence =  -0.00017, Steps =  8
# Point  396: ΔLoss =  0.0380,  ΔLoss_tilde =  0.0378, Influence =   0.02122, Steps =  8
# Point  397: ΔLoss =  0.0053,  ΔLoss_tilde =  0.0053, Influence =   0.00484, Steps =  8
# Point  398: ΔLoss = -0.0572,  ΔLoss_tilde = -0.0574, Influence =  -0.03176, Steps =  8
# Point  399: ΔLoss = -0.0612,  ΔLoss_tilde = -0.0613, Influence =  -0.03647, Steps =  8
# Point  400: ΔLoss =  0.0565,  ΔLoss_tilde =  0.0562, Influence =   0.01739, Steps =  8
# Point  401: ΔLoss = -0.0544,  ΔLoss_tilde = -0.0545, Influence =  -0.02740, Steps =  8
# Point  402: ΔLoss =  0.0179,  ΔLoss_tilde =  0.0176, Influence =   0.00845, Steps =  8
# Point  403: ΔLoss = -0.0748,  ΔLoss_tilde = -0.0746, Influence =  -0.03465, Steps =  8
# Point  404: ΔLoss =  0.0979,  ΔLoss_tilde =  0.0975, Influence =   0.04169, Steps =  8
# Point  405: ΔLoss = -0.0141,  ΔLoss_tilde = -0.0148, Influence =  -0.00487, Steps =  8
# Point  406: ΔLoss = -0.0754,  ΔLoss_tilde = -0.0764, Influence =  -0.03204, Steps =  8
# Point  407: ΔLoss = -0.0159,  ΔLoss_tilde = -0.0161, Influence =  -0.00999, Steps =  8
# Point  408: ΔLoss = -0.0698,  ΔLoss_tilde = -0.0695, Influence =  -0.02175, Steps =  8
# Point  409: ΔLoss =  0.0496,  ΔLoss_tilde =  0.0497, Influence =   0.02176, Steps =  8
# Point  410: ΔLoss = -0.0254,  ΔLoss_tilde = -0.0254, Influence =  -0.02511, Steps =  8
# Point  411: ΔLoss =  0.0027,  ΔLoss_tilde =  0.0040, Influence =   0.00147, Steps =  8
# Point  412: ΔLoss = -0.0248,  ΔLoss_tilde = -0.0248, Influence =  -0.01734, Steps =  8
# Point  413: ΔLoss =  0.0146,  ΔLoss_tilde =  0.0147, Influence =   0.01123, Steps =  8
# Point  414: ΔLoss =  0.0534,  ΔLoss_tilde =  0.0530, Influence =   0.02111, Steps =  8
# Point  415: ΔLoss = -0.0324,  ΔLoss_tilde = -0.0324, Influence =  -0.01925, Steps =  8
# Point  416: ΔLoss = -0.0079,  ΔLoss_tilde = -0.0078, Influence =  -0.00329, Steps =  8
# Point  417: ΔLoss = -0.0067,  ΔLoss_tilde = -0.0068, Influence =  -0.00643, Steps =  8
# Point  418: ΔLoss = -0.0086,  ΔLoss_tilde = -0.0086, Influence =  -0.00920, Steps =  8
# Point  419: ΔLoss =  0.0624,  ΔLoss_tilde =  0.0626, Influence =   0.02859, Steps =  8
# Point  420: ΔLoss =  0.0110,  ΔLoss_tilde =  0.0110, Influence =   0.00896, Steps =  8
# Point  421: ΔLoss =  0.0242,  ΔLoss_tilde =  0.0229, Influence =   0.00622, Steps =  8
# Point  422: ΔLoss = -0.0016,  ΔLoss_tilde = -0.0016, Influence =  -0.00223, Steps =  8
# Point  423: ΔLoss = -0.1223,  ΔLoss_tilde = -0.1220, Influence =  -0.04936, Steps =  8
# Point  424: ΔLoss = -0.0250,  ΔLoss_tilde = -0.0251, Influence =  -0.01974, Steps =  8
# Point  425: ΔLoss = -0.0059,  ΔLoss_tilde = -0.0053, Influence =  -0.00203, Steps =  8
# Point  426: ΔLoss =  0.0012,  ΔLoss_tilde =  0.0013, Influence =   0.00092, Steps =  8
# Point  427: ΔLoss =  0.0224,  ΔLoss_tilde =  0.0221, Influence =   0.00946, Steps =  8
# Point  428: ΔLoss =  0.0524,  ΔLoss_tilde =  0.0516, Influence =   0.01810, Steps =  8
# Point  429: ΔLoss =  0.0673,  ΔLoss_tilde =  0.0721, Influence =   0.01302, Steps =  8
# Point  430: ΔLoss =  0.0488,  ΔLoss_tilde =  0.0487, Influence =   0.02350, Steps =  8
# Point  431: ΔLoss =  0.0160,  ΔLoss_tilde =  0.0158, Influence =   0.00831, Steps =  8
# Point  432: ΔLoss =  0.0676,  ΔLoss_tilde =  0.0662, Influence =   0.02087, Steps =  8
# Point  433: ΔLoss = -0.0060,  ΔLoss_tilde = -0.0060, Influence =  -0.00936, Steps =  8
# Point  434: ΔLoss =  0.0089,  ΔLoss_tilde =  0.0089, Influence =   0.00664, Steps =  8
# Point  435: ΔLoss = -0.0451,  ΔLoss_tilde = -0.0451, Influence =  -0.02984, Steps =  8
# Point  436: ΔLoss =  0.0939,  ΔLoss_tilde =  0.0927, Influence =   0.02200, Steps =  8
# Point  437: ΔLoss = -0.0215,  ΔLoss_tilde = -0.0214, Influence =  -0.01124, Steps =  8
# Point  438: ΔLoss =  0.0280,  ΔLoss_tilde =  0.0280, Influence =   0.01939, Steps =  8
# Point  439: ΔLoss =  0.0842,  ΔLoss_tilde =  0.0827, Influence =   0.02605, Steps =  8
# Point  440: ΔLoss =  0.0536,  ΔLoss_tilde =  0.0532, Influence =   0.01550, Steps =  8
# Point  441: ΔLoss =  0.0177,  ΔLoss_tilde =  0.0168, Influence =   0.00575, Steps =  8
# Point  442: ΔLoss =  0.0455,  ΔLoss_tilde =  0.0459, Influence =   0.02518, Steps =  8
# Point  443: ΔLoss =  0.0373,  ΔLoss_tilde =  0.0373, Influence =   0.02704, Steps =  8
# Point  444: ΔLoss =  0.0245,  ΔLoss_tilde =  0.0251, Influence =   0.01017, Steps =  8
# Point  445: ΔLoss =  0.0919,  ΔLoss_tilde =  0.0916, Influence =   0.04303, Steps =  8
# Point  446: ΔLoss =  0.0849,  ΔLoss_tilde =  0.0843, Influence =   0.02128, Steps =  8
# Point  447: ΔLoss =  0.0350,  ΔLoss_tilde =  0.0352, Influence =   0.01463, Steps =  8
# Point  448: ΔLoss = -0.0265,  ΔLoss_tilde = -0.0267, Influence =  -0.01175, Steps =  8
# Point  449: ΔLoss = -0.0875,  ΔLoss_tilde = -0.0872, Influence =  -0.03987, Steps =  8
# Point  450: ΔLoss =  0.0461,  ΔLoss_tilde =  0.0462, Influence =   0.02369, Steps =  8
# Point  451: ΔLoss = -0.0190,  ΔLoss_tilde = -0.0190, Influence =  -0.01702, Steps =  8
# Point  452: ΔLoss = -0.0269,  ΔLoss_tilde = -0.0270, Influence =  -0.02104, Steps =  8
# Point  453: ΔLoss = -0.0720,  ΔLoss_tilde = -0.0723, Influence =  -0.02607, Steps =  8
# Point  454: ΔLoss =  0.0504,  ΔLoss_tilde =  0.0503, Influence =   0.02052, Steps =  8
# Point  455: ΔLoss =  0.0133,  ΔLoss_tilde =  0.0133, Influence =   0.00950, Steps =  8
# Point  456: ΔLoss = -0.0112,  ΔLoss_tilde = -0.0114, Influence =  -0.00643, Steps =  8
# Point  457: ΔLoss =  0.1077,  ΔLoss_tilde =  0.1075, Influence =   0.03434, Steps =  8
# Point  458: ΔLoss = -0.0205,  ΔLoss_tilde = -0.0207, Influence =  -0.01244, Steps =  8
# Point  459: ΔLoss =  0.1131,  ΔLoss_tilde =  0.1136, Influence =   0.03199, Steps =  8
# Point  460: ΔLoss =  0.0108,  ΔLoss_tilde =  0.0108, Influence =   0.00819, Steps =  8
# Point  461: ΔLoss =  0.1247,  ΔLoss_tilde =  0.1250, Influence =   0.04873, Steps =  8
# Point  462: ΔLoss =  0.0385,  ΔLoss_tilde =  0.0385, Influence =   0.02688, Steps =  8
# Point  463: ΔLoss =  0.0055,  ΔLoss_tilde =  0.0056, Influence =   0.00653, Steps =  8
# Point  464: ΔLoss = -0.1324,  ΔLoss_tilde = -0.1322, Influence =  -0.05445, Steps =  8
# Point  465: ΔLoss = -0.0018,  ΔLoss_tilde = -0.0019, Influence =  -0.00095, Steps =  8
# Point  466: ΔLoss =  0.0375,  ΔLoss_tilde =  0.0376, Influence =   0.02362, Steps =  8
# Point  467: ΔLoss =  0.0030,  ΔLoss_tilde =  0.0030, Influence =   0.00466, Steps =  8
# Point  468: ΔLoss = -0.0183,  ΔLoss_tilde = -0.0183, Influence =  -0.02441, Steps =  8
# Point  469: ΔLoss = -0.0001,  ΔLoss_tilde = -0.0001, Influence =  -0.00028, Steps =  8
# Point  470: ΔLoss = -0.0720,  ΔLoss_tilde = -0.0717, Influence =  -0.04190, Steps =  8
# Point  471: ΔLoss =  0.0094,  ΔLoss_tilde =  0.0094, Influence =   0.00576, Steps =  8
# Point  472: ΔLoss = -0.0366,  ΔLoss_tilde = -0.0368, Influence =  -0.02001, Steps =  8
# Point  473: ΔLoss =  0.0028,  ΔLoss_tilde =  0.0019, Influence =   0.00064, Steps =  8
# Point  474: ΔLoss =  0.0162,  ΔLoss_tilde =  0.0162, Influence =   0.02176, Steps =  8
# Point  475: ΔLoss =  0.0083,  ΔLoss_tilde =  0.0083, Influence =   0.01008, Steps =  8
# Point  476: ΔLoss =  0.0097,  ΔLoss_tilde =  0.0097, Influence =   0.00800, Steps =  8
# Point  477: ΔLoss =  0.0319,  ΔLoss_tilde =  0.0317, Influence =   0.01262, Steps =  8
# Point  478: ΔLoss = -0.0244,  ΔLoss_tilde = -0.0241, Influence =  -0.01014, Steps =  8
# Point  479: ΔLoss =  0.2157,  ΔLoss_tilde =  0.2151, Influence =   0.05903, Steps =  8
# Point  480: ΔLoss = -0.0002,  ΔLoss_tilde = -0.0002, Influence =  -0.00017, Steps =  8
# Point  481: ΔLoss =  0.0422,  ΔLoss_tilde =  0.0417, Influence =   0.01422, Steps =  8
# Point  482: ΔLoss =  0.2201,  ΔLoss_tilde =  0.2200, Influence =   0.08050, Steps =  8
# Point  483: ΔLoss =  0.0968,  ΔLoss_tilde =  0.0972, Influence =   0.03782, Steps =  8
# Point  484: ΔLoss = -0.0614,  ΔLoss_tilde = -0.0613, Influence =  -0.02522, Steps =  8
# Point  485: ΔLoss = -0.0123,  ΔLoss_tilde = -0.0124, Influence =  -0.00543, Steps =  8
# Point  486: ΔLoss = -0.0030,  ΔLoss_tilde = -0.0030, Influence =  -0.00201, Steps =  8
# Point  487: ΔLoss = -0.0045,  ΔLoss_tilde = -0.0053, Influence =  -0.00199, Steps =  8
# Point  488: ΔLoss = -0.0493,  ΔLoss_tilde = -0.0492, Influence =  -0.02053, Steps =  8
# Point  489: ΔLoss =  0.0307,  ΔLoss_tilde =  0.0307, Influence =   0.01338, Steps =  8
# Point  490: ΔLoss =  0.0804,  ΔLoss_tilde =  0.0797, Influence =   0.01862, Steps =  8
# Point  491: ΔLoss =  0.0761,  ΔLoss_tilde =  0.0764, Influence =   0.03380, Steps =  8
# Point  492: ΔLoss =  0.0080,  ΔLoss_tilde =  0.0078, Influence =   0.00335, Steps =  8
# Point  493: ΔLoss = -0.0057,  ΔLoss_tilde = -0.0057, Influence =  -0.00876, Steps =  8
# Point  494: ΔLoss =  0.1104,  ΔLoss_tilde =  0.1096, Influence =   0.04133, Steps =  8
# Point  495: ΔLoss =  0.1175,  ΔLoss_tilde =  0.1175, Influence =   0.03993, Steps =  8
# Point  496: ΔLoss = -0.0217,  ΔLoss_tilde = -0.0211, Influence =  -0.00614, Steps =  8
# Point  497: ΔLoss =  0.0660,  ΔLoss_tilde =  0.0655, Influence =   0.02565, Steps =  8
# Point  498: ΔLoss =  0.0234,  ΔLoss_tilde =  0.0247, Influence =   0.00697, Steps =  8
# Point  499: ΔLoss = -0.0186,  ΔLoss_tilde = -0.0186, Influence =  -0.01408, Steps =  8

# %%
import numpy as np
from scipy.stats import kendalltau, spearmanr
import matplotlib.pyplot as plt
#plt.rcParams['text.usetex'] = False  # Set to True if using full LaTeX setup


# Prepare storage
kendall_tilde_values = []
kendall_infl_values = []
spearman_tilde_values = []
spearman_infl_values = []

n_train, m_test = loss_changes.shape

# Loop over each test point (column-wise)
for j in range(m_test):
    a = loss_changes[:, j]
    a_tilde = approx_loss_changes[:, j]
    a_infl = influence_values[:, j]

    # Compute correlations
    tau_tilde, _ = kendalltau(a, a_tilde)
    tau_infl, _ = kendalltau(a, a_infl)
    rho_tilde, _ = spearmanr(a, a_tilde)
    rho_infl, _ = spearmanr(a, a_infl)

    # Store them
    kendall_tilde_values.append(tau_tilde)
    kendall_infl_values.append(tau_infl)
    spearman_tilde_values.append(rho_tilde)
    spearman_infl_values.append(rho_infl)

# Convert lists to arrays
kendall_tilde_values = np.array(kendall_tilde_values)
kendall_infl_values = np.array(kendall_infl_values)
spearman_tilde_values = np.array(spearman_tilde_values)
spearman_infl_values = np.array(spearman_infl_values)



# Mean and standard deviation for Kendall's Tau

def print_mean_std(name, data):
    mean = np.mean(data)
    std = np.std(data)
    print(f"{name}:")
    print(f"  Mean = {mean:.4f}")
    print(f"  Std  = {std:.4f}\n")

print_mean_std("Kendall's Tau (Newfluence)", kendall_tilde_values)
print_mean_std("Kendall's Tau (Influence)", kendall_infl_values)


# === Add Scatter Plots ===
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Flatten everything
exact = loss_changes.flatten()
tilde = approx_loss_changes.flatten()
influence = influence_values.flatten()
line = np.linspace(np.min(exact), np.max(exact), 100)

# Scatter: Approx vs True
axes[0].scatter(exact, tilde, s=10, alpha=0.5, label="Newfluence vs True influence")
axes[0].plot(line, line, color='red', linestyle='--', label='y = x')
axes[0].grid(True)
axes[0].set_title("Newfluence vs True influence")
axes[1].set_xlabel(r"$\mathcal{I}^{\text{True}}(\mathbf{z}_i, \mathbf{z}_{\text{test}})$")
axes[0].set_ylabel(r"$\mathcal{I}^{\text{New}}(\mathbf{z}_i, \mathbf{z}_{\text{test}})$")
axes[0].legend()

# Scatter: Influence vs True
axes[1].scatter(exact, influence, s=10, alpha=0.5, label="Classical vs True influence")
axes[1].plot(line, line, color='red', linestyle='--', label='y = x')
axes[1].grid(True)
axes[1].set_title("Classical vs True influence")
#axes[1].set_xlabel("True influence")
axes[1].set_xlabel(r"$\mathcal{I}^{\text{True}}(\mathbf{z}_i, \mathbf{z}_{\text{test}})$")
axes[1].set_ylabel(r"$\mathcal{I}^{\text{IF}}(\mathbf{z}_i, \mathbf{z}_{\text{test}})$")
axes[1].legend()


plt.tight_layout()
plt.show()

# Convert to arrays (if not already)
kendall_tilde = np.array(kendall_tilde_values)
kendall_infl = np.array(kendall_infl_values)

# Define function for five-number summary
def five_number_summary(x):
    return {
        "Min": np.min(x),
        "Q1": np.percentile(x, 25),
        "Median": np.median(x),
        "Q3": np.percentile(x, 75),
        "Max": np.max(x)
    }

# Compute summaries
summary_tilde = five_number_summary(kendall_tilde)
summary_infl = five_number_summary(kendall_infl)

# Print results
print("\nFive-number summary of Kendall's tau (Newfluence):")
for k, v in summary_tilde.items():
    print(f"{k:>6}: {v:.4f}")

print("\nFive-number summary of Kendall's tau (Classical influence):")
for k, v in summary_infl.items():
    print(f"{k:>6}: {v:.4f}")
# Out:
# Kendall's Tau (Newfluence):
#   Mean = 0.9957
#   Std  = 0.0007
#
# Kendall's Tau (Influence):
#   Mean = 0.8834
#   Std  = 0.0051
# Five-number summary of Kendall's tau (Newfluence):
#    Min: 0.9931
#     Q1: 0.9954
# Median: 0.9958
#     Q3: 0.9961
#    Max: 0.9970
#
# Five-number summary of Kendall's tau (Classical influence):
#    Min: 0.8699
#     Q1: 0.8801
# Median: 0.8840
#     Q3: 0.8876
#    Max: 0.8946

# %%
import numpy as np
import pandas as pd
from scipy.stats import kendalltau

# Core logistic regression utilities
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def gradient(beta, X, y, lambda_):
    p = sigmoid(X @ beta)
    return -X.T @ (y - p) + lambda_ * beta

def hessian(beta, X, lambda_):
    p = sigmoid(X @ beta)
    w = p * (1 - p)
    WX = X * w[:, np.newaxis]
    return X.T @ WX + lambda_ * np.eye(X.shape[1])

def newton_step(beta_init, X, y, lambda_, tol=1e-6, max_iter=100):
    beta = beta_init.copy()
    for _ in range(max_iter):
        grad = gradient(beta, X, y, lambda_)
        hess = hessian(beta, X, lambda_)
        step = np.linalg.solve(hess, grad)
        beta -= step
        if np.linalg.norm(step) < tol:
            break
    return beta

# Experimental setup
lambda_ = 10
m = 100  # number of test points
n_p_ratio = 0.5
p_list = [500, 1000, 2000]  # change p, n changes accordingly

results = []

for p in p_list:
    n = int(n_p_ratio * p)
    np.random.seed(1)

    # Data generation
    beta_star = np.random.normal(0, 1, p)
    X = np.random.normal(0, 1 / np.sqrt(n), size=(n, p))
    logits = X @ beta_star
    prob = sigmoid(logits)
    y = np.random.binomial(1, prob)
    beta_init = np.random.normal(0, 1, p) * 0.01
    beta_hat = newton_step(beta_init, X, y, lambda_)

    # Test set
    X_new = np.random.normal(0, 1 / np.sqrt(n), size=(m, p))
    logits_new = X_new @ beta_star
    probs_new = sigmoid(logits_new)
    y_new = np.random.binomial(1, probs_new)
    logits_full = X_new @ beta_hat
    loss_full = -y_new * logits_full + np.log(1 + np.exp(logits_full))

    # Preallocate
    loss_changes = np.zeros((n, m))
    approx_loss_changes = np.zeros((n, m))
    influence_values = np.zeros((n, m))

    # Hessian
    eta = X @ beta_hat
    p_hat = sigmoid(eta)
    w = p_hat * (1 - p_hat)
    WX = X * w[:, np.newaxis]
    hessian_matrix = X.T @ WX + lambda_ * np.eye(p)
    hessian_inv = np.linalg.solve(hessian_matrix, np.eye(p))
    H_diag = np.einsum('ij,jk,ik->i', X, hessian_inv, X) * w
    effective_df = np.sum(H_diag) / p

    # Loop over training points
    for i in range(n):
        X_minus_i = np.delete(X, i, axis=0)
        y_minus_i = np.delete(y, i)
        beta_hat_minus_i = newton_step(np.random.normal(0, 1, p) * 0.01, X_minus_i, y_minus_i, lambda_)
        logits_minus_i = X_new @ beta_hat_minus_i
        loss_minus_i = -y_new * logits_minus_i + np.log(1 + np.exp(logits_minus_i))
        loss_changes[i, :] = loss_minus_i - loss_full

        # Approx beta_{-i}
        p_i = p_hat[i]
        y_i = y[i]
        x_i = X[i]
        grad_i = (p_i - y_i) * x_i
        w_minus_i = np.delete(w, i)
        WX_i = X_minus_i * w_minus_i[:, np.newaxis]
        hessian_i = X_minus_i.T @ WX_i + lambda_ * np.eye(p)
        hessian_i_inv = np.linalg.solve(hessian_i, np.eye(p))
        beta_tilde_i = beta_hat + hessian_i_inv @ grad_i
        logits_tilde_i = X_new @ beta_tilde_i
        loss_tilde_i = -y_new * logits_tilde_i + np.log(1 + np.exp(logits_tilde_i))
        approx_loss_changes[i, :] = loss_tilde_i - loss_full

        for j in range(m):
            p_new = probs_new[j]
            grad_test = (p_new - y_new[j]) * X_new[j]
            influence_values[i, j] = grad_test @ hessian_inv @ grad_i

    # Compute Kendall’s Tau per test point
    kendall_approx = []
    kendall_infl = []
    for j in range(m):
        tau1, _ = kendalltau(loss_changes[:, j], approx_loss_changes[:, j])
        tau2, _ = kendalltau(loss_changes[:, j], influence_values[:, j])
        kendall_approx.append(tau1)
        kendall_infl.append(tau2)

    # Compute and store results
    result_entry = {
    "n": n,
    "p": p,
    "n/p": n / p,
    "lambda": lambda_,
    "effective_df": effective_df,
    "kendall_approx_mean": np.nanmean(kendall_approx),
    "kendall_approx_std": np.nanstd(kendall_approx),
    "kendall_infl_mean": np.nanmean(kendall_infl),
    "kendall_infl_std": np.nanstd(kendall_infl),
    }

    # Append to results list
    results.append(result_entry)

    # === Print progress ===
    print(f"Finished: n={n}, p={p}")
    print(f"  eff_df = {effective_df:.4f}")
    print(f"  Kendall approx: mean={result_entry['kendall_approx_mean']:.4f}, std={result_entry['kendall_approx_std']:.4f}")
    print(f"  Kendall infl  : mean={result_entry['kendall_infl_mean']:.4f}, std={result_entry['kendall_infl_std']:.4f}")
    print("-" * 60)


# Save and show results
results_df = pd.DataFrame(results)
print("\n=== Summary Results ===")
print(results_df)
# Out:
# Finished: n=250, p=500
#   eff_df = 0.0231
#   Kendall approx: mean=1.0000, std=0.0000
#   Kendall infl  : mean=0.9989, std=0.0003
# ------------------------------------------------------------
# Finished: n=500, p=1000
#   eff_df = 0.0232
#   Kendall approx: mean=1.0000, std=0.0000
#   Kendall infl  : mean=0.9992, std=0.0001
# ------------------------------------------------------------
# Finished: n=1000, p=2000
#   eff_df = 0.0232
#   Kendall approx: mean=1.0000, std=0.0000
#   Kendall infl  : mean=0.9995, std=0.0000
# ------------------------------------------------------------
#
# === Summary Results ===
#       n     p  n/p  lambda  effective_df  kendall_approx_mean  \
# 0   250   500  0.5      10      0.023141             0.999995
# 1   500  1000  0.5      10      0.023165             0.999998
# 2  1000  2000  0.5      10      0.023170             0.999998
#
#    kendall_approx_std  kendall_infl_mean  kendall_infl_std
# 0            0.000017           0.998924          0.000259
# 1            0.000006           0.999227          0.000110
# 2            0.000003           0.999505          0.000045

# %%
# Use values from the first row for shared lambda and df/p
lambda_val = results_df['lambda'].iloc[0]
df_per_p = results_df['effective_df'].iloc[0]

# Start LaTeX table
latex_table = r"""
\begin{table}[ht]
\centering
\begin{tabular}{rrrr}
\toprule
$n$ & $p$ & $\tau$ (Newfluence) & $\tau$ (IF) \\
\midrule
"""

# Add table rows
for _, row in results_df.iterrows():
    n = int(row['n'])
    p = int(row['p'])
    tau_alo = f"{row['kendall_approx_mean']:.2f} ({row['kendall_approx_std']:.2f})"
    tau_infl = f"{row['kendall_infl_mean']:.2f} ({row['kendall_infl_std']:.2f})"
    latex_table += f"{n} & {p} & {tau_alo} & {tau_infl} \\\\\n"

# Close the table and add caption with f-string only
latex_table += (
    r"""\bottomrule
\end{tabular}
\caption{Kendall's $\tau$ (mean and std in parentheses) for Newfluence and classical influence-based  estimates across different training set sizes computed over a $m=100$ unseen test data points for logistic ridge when """
    + f"$\\lambda={lambda_val:.2f}$, leading to $\\text{{df}}/p={df_per_p:.3f}$."
    + r"""}
\label{tab:kendall_compact}
\end{table}
"""
)

# Print final LaTeX table
print(latex_table)
# Out:
# \begin{table}[ht]
# \centering
# \begin{tabular}{rrrr}
# \toprule
# $n$ & $p$ & $\tau$ (ALO) & $\tau$ (influence) \\
# \midrule
# 250 & 500 & 1.00 (0.00) & 1.00 (0.00) \\
# 500 & 1000 & 1.00 (0.00) & 1.00 (0.00) \\
# 1000 & 2000 & 1.00 (0.00) & 1.00 (0.00) \\
# \bottomrule
# \end{tabular}
# \caption{Kendall's $\tau$ (mean and std in parentheses) for ALO-based and classical influence-based loss change estimates across different training set sizes computed over a $m=100$ unseen test data points for logistic ridge when $\lambda=10.00$, leading to $\text{df}/p=0.023$.}
# \label{tab:kendall_compact}
# \end{table}
